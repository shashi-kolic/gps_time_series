# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import math
from scipy.optimize import minimize
from numpy.linalg import inv
import scipy.fft as fft

# %%
#--- power-law noise covariance matrix
def create_C(sigma_pl,kappa):
    U = np.identity(N)
    h_prev = 1
    for i in range(1,N):
        h = (i-kappa/2-1)/i * h_prev # Eq. (25)
        for j in range(0,N-i):
            U[j,j+i] = h
        h_prev = h
    U *= sigma_pl # scale noise
    return U.T @ U # Eq. (26)


#--- weighted least-squares
def leastsquares(C,A,y):
    U = np.linalg.cholesky(C).T
    U_inv = inv(U)
    B = U_inv.T @ A
    z = U_inv.T @ y
    x = inv(B.T @ B) @ B.T @ z # Eq. (14)
    #--- variance of the estimated parameters
    C_x = inv(B.T @ B) # Eq. (15)
    #--- Compute log of determinant of C
    ln_det_C = 0.0
    for i in range(0,N):
        ln_det_C += 2*math.log(U[i,i])
    return [x,C_x,ln_det_C]

# %%
data = pd.read_csv('ALBH.csv')

# %%
data.head()
# Out:
#          date   north    east   site               Lat                Long
# 0  2015-01-01 -151.87 -142.33   ALBH   48.3897811345 N   -123.4874707769 E
# 1  2015-01-02 -151.76 -142.48    NaN               NaN                 NaN
# 2  2015-01-03 -152.28 -142.24    NaN               NaN                 NaN
# 3  2015-01-04 -152.63 -142.63    NaN               NaN                 NaN
# 4  2015-01-05 -153.09 -143.03    NaN               NaN                 NaN

# %%
date = data.iloc[:,0]
x_north = data.iloc[:,1].values
x_east = data.iloc[:,2].values

# %%
len(x_north)
# Out:
# 1348

# %%
date_ = np.array([])
for i in range(0,len(date)):
    temp = date[i]
    date_temp = datetime.strptime(temp, "%Y-%m-%d")
    date_ = np.append(date_temp, date_)
date_= np.flipud(date_)

# %%
time = np.array([])
for i in range(0,len(date)):
    temp = (date_[i]-date_[0]).days
    time = np.append(time,temp)

# %%
time = time/365.25

# %%
plt.figure(figsize=(10,10))
plt.scatter(time,x_north)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.scatter(time,x_east)
plt.show()

# %% [markdown]
# ### Applying RANSAC Regression to detect outliers

# %%
from sklearn.linear_model import RANSACRegressor
ransac_mod = RANSACRegressor()
ransac_mod.fit(time.reshape(-1,1),x_north.reshape(-1,1))

ransac_mod2 = RANSACRegressor()
ransac_mod2.fit(time.reshape(-1,1),x_east.reshape(-1,1))
# Out:
# RANSACRegressor(base_estimator=None, is_data_valid=None, is_model_valid=None,
#                 loss='absolute_loss', max_skips=inf, max_trials=100,
#                 min_samples=None, random_state=None, residual_threshold=None,
#                 stop_n_inliers=inf, stop_probability=0.99, stop_score=inf)

# %%
north = x_north[ransac_mod.inlier_mask_]
east = x_east[ransac_mod2.inlier_mask_]
t_north = time[ransac_mod.inlier_mask_]
t_east = time[ransac_mod2.inlier_mask_]

# %%
plt.figure(figsize=(10,10))
plt.plot(t_north,north)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(t_east,east)
plt.show()

# %% [markdown]
# #        North

# %%
# --- Design Matrix

N = len(t_north)
A = np.empty((N,2))

for i in range(0,N):
    A[i,0] = 1
    A[i,1] = t_north[i]

# %% [markdown]
# ### Modeling Assuming White Noise

# %%
# --- Old White Noise Method

C = np.identity(N)
x = inv(A.T @ inv(C) @ A) @ (A.T @ inv(C) @ north)

north_hat = A @ x
r = north - north_hat #residuals

C_x = np.var(r)* inv(A.T @ inv(C) @ A)

# %%
print('White Noise Approximation')
print('a = {0:6.3f} +/- {1:5.3f} mm '.format(x[0],math.sqrt(C_x[0,0])))
print('b = {0:6.3f} +/- {1:5.3f} mm/yr '.format(x[1],math.sqrt(C_x[1,1])))
a1=x[0]
b1=x[1]
white_v_north = b1
white_v_north_unc = math.sqrt(C_x[1,1])
# Out:
# White Noise Approximation
# a = -150.742 +/- 0.055 mm
# b = -7.623 +/- 0.026 mm/yr

# %% [markdown]
# ### Modeling Using Power Law Distribution

# %%
#--- Log-likelihood (with opposite sign)
def log_likelihood(x_noise):
    sigma_pl = x_noise[0]
    kappa = x_noise[1]
    C = create_C(sigma_pl,kappa)
    [x,C_x,ln_det_C] = leastsquares(C,A,north)
    r = north - A @ x # residuals
    #--- Eq. (12)
    logL = -0.5*(N*math.log(2*math.pi) + ln_det_C + r.T @ inv(C) @ r)
    return -logL

x_noise0 = np.array([1,1]) # sigma_pl and kappa guesses
res = minimize(log_likelihood, x_noise0, \
method='nelder-mead', options={'xatol':0.01})
print('sigma_pl={0:6.3f}, kappa={1:6.3f}'.format(res.x[0],res.x[1]))
# Out:
# sigma_pl= 0.725, kappa=-0.789

# %%
#--- The correct noise covariance matrix
sigma_pl = res.x[0]
kappa = res.x[1]
C = create_C(sigma_pl,kappa)
[x,C_x,ln_det_C] = leastsquares(C,A,north)
print('Correct Flicker noise')
print('a = {0:6.3f} +/- {1:5.3f} mm'.format(x[0],\
math.sqrt(C_x[0,0])))
print('b = {0:6.3f} +/- {1:5.3f} mm/yr'.format(x[1],\
math.sqrt(C_x[1,1])))
a2= x[0]
b2=x[1]
power_v_north = b2
power_v_north_unc = math.sqrt(C_x[1,1])
kappa_north = res.x[1]
sigma_north = res.x[0]
# Out:
# Correct Flicker noise
# a = -151.341 +/- 0.305 mm
# b = -7.529 +/- 0.152 mm/yr

# %%
plt.figure(figsize=(15,10))
p1 = plt.plot(t_north, north, color = 'black')
p3 = plt.plot(t_north,a1+b1*t_north,color='green',label='White Noise ')
p4 = plt.plot(t_north,a2+b2*t_north,color='red',label='Power-Law Noise ')
plt.legend()
plt.xlabel('Time (in year)')
plt.ylabel('Displacement (in mm)')
plt.title('ALBH (North) ( From 01-01-2015 to 15-09-2018 )')
plt.savefig('ALBH-North')
plt.show()

# %%
res_north = north-A@x

# %%
plt.figure(figsize=(12,10))
p1 = plt.plot(t_north, res_north, color = 'black')
plt.title('Residual - North')
plt.show()

# %% [markdown]
# # East

# %%
# --- Design Matrix

N = len(t_east)
A = np.empty((N,2))

for i in range(0,N):
    A[i,0] = 1
    A[i,1] = t_east[i]

# %% [markdown]
# ### Modeling Assuming White Noise

# %%
# --- Old White Noise Method

C = np.identity(N)
x = inv(A.T @ inv(C) @ A) @ (A.T @ inv(C) @ east)

east_hat = A @ x
r = east - east_hat #residuals

C_x = np.var(r)* inv(A.T @ inv(C) @ A)

# %%
print('White Noise Approximation')
print('a = {0:6.3f} +/- {1:5.3f} mm '.format(x[0],math.sqrt(C_x[0,0])))
print('b = {0:6.3f} +/- {1:5.3f} mm/yr '.format(x[1],math.sqrt(C_x[1,1])))
a1=x[0]
b1=x[1]
white_v_east = b1
white_v_east_unc = math.sqrt(C_x[1,1])
# Out:
# White Noise Approximation
# a = -142.363 +/- 0.084 mm
# b = -8.007 +/- 0.039 mm/yr

# %% [markdown]
# ### Modeling Using Power Law Distribution

# %%
#--- Log-likelihood (with opposite sign)
def log_likelihood(x_noise):
    sigma_pl = x_noise[0]
    kappa = x_noise[1]
    C = create_C(sigma_pl,kappa)
    [x,C_x,ln_det_C] = leastsquares(C,A,east)
    r = east - A @ x # residuals
    
    logL = -0.5*(N*math.log(2*math.pi) + ln_det_C + r.T @ inv(C) @ r)
    return -logL

x_noise0 = np.array([1,1]) # sigma_pl and kappa guesses
res = minimize(log_likelihood, x_noise0, \
method='nelder-mead', options={'xatol':0.01})
print('sigma_pl={0:6.3f}, kappa={1:6.3f}'.format(res.x[0],res.x[1]))
# Out:
# sigma_pl= 0.786, kappa=-0.972

# %%
#--- The correct noise covariance matrix
sigma_pl = res.x[0]
kappa = res.x[1]
C = create_C(sigma_pl,kappa)
[x,C_x,ln_det_C] = leastsquares(C,A,east)
print('Correct noise')
print('a = {0:6.3f} +/- {1:5.3f} mm'.format(x[0],\
math.sqrt(C_x[0,0])))
print('b = {0:6.3f} +/- {1:5.3f} mm/yr'.format(x[1],\
math.sqrt(C_x[1,1])))
a2=x[0]
b2=x[1]
power_v_east = b2
power_v_east_unc = math.sqrt(C_x[1,1])
kappa_east = res.x[1]
sigma_east = res.x[0]
# Out:
# Correct noise
# a = -142.221 +/- 0.457 mm
# b = -8.022 +/- 0.272 mm/yr

# %%
plt.figure(figsize=(15,10))
p1 = plt.plot(t_east, east, color = 'black')
p3 = plt.plot(t_east,a1+b1*t_east,color='green',label='White-Noise')
p4 = plt.plot(t_east,a2+b2*t_east,color='red',label='Power-law noise')
plt.legend()

plt.xlabel('Time (in year)')
plt.ylabel('Displacement (in mm)')
plt.title('ALBH (East) ( From 01-01-2015 to 15-09-2018 )')
plt.savefig('ALBH-East')
plt.show()

# %%
res_east = east-A@x

# %%
plt.figure(figsize=(12,10))
p1 = plt.plot(t_east, res_east, color = 'black')
plt.title('Residual-East')
plt.show()

# %%
##### print('White Noise')
print('')
print('        NORTH        ')
print('V_north -->',  white_v_north)
print('V_north_unc -->',  white_v_north_unc)
print('        EAST        ')
print('V_east -->',  white_v_east)
print('V_east_unc -->',  white_v_east_unc)
print('')

print('Power Law Noise')

print('')
print('        NORTH        ')

print('power_v_north -->', power_v_north)
print('power_v_north_unc -->',power_v_north_unc)
print('kappa_north -->',kappa_north)
print('sigma_north -->', sigma_north)
print('')
print('        EAST        ')
print('power_v_east -->', power_v_east)
print('power_v_east_unc -->',power_v_east_unc)
print('kappa_east -->',kappa_east)
print('sigma_east -->', sigma_east)
# Out:
#         NORTH
# V_north --> -7.622930737759589
# V_north_unc --> 0.025886451132504238
#         EAST
# V_east --> -8.006652528535795
# V_east_unc --> 0.039063700978547486
#
# Power Law Noise
#
#         NORTH
# power_v_north --> -7.529233603603602
# power_v_north_unc --> 0.15177690674462385
# kappa_north --> -0.7889722369024661
# sigma_north --> 0.7254734473714617
#
#         EAST
# power_v_east --> -8.02192440312256
# power_v_east_unc --> 0.27227211763657705
# kappa_east --> -0.9719424406904971
# sigma_east --> 0.7860000150578978

# %%
# Markov Chain Monte Carlo Method

import scipy
import pymc3 as pm


x = t_north
y = north

with pm.Model() as linear_model:
    #Intercept
    intercept = pm.Normal('Intercept' , mu = 0, sd = 10)
    
    #Slope
    slope =  pm.Normal('Slope' , mu =0,  sd = 10)
    
    #Standard Deviation
    sigma  = pm.HalfNormal('sigma', sd = 10)
    
    #Estimation of Mean
    mean = intercept + slope*x
    
    #observed values
    
    Y_obs = pm.Normal('Y_obs', mu = mean, sd = sigma, observed = y)
    
    #sampler
    step = pm.NUTS()
    
    #Posterior Distribution
    linear_trace = pm.sample(10000,step)
    

pm.traceplot(linear_trace, figsize = (20, 20))
plt.savefig('ALBH - North (MCMC)')

summary = pm.summary(linear_trace)
v_north = summary.iloc[1,0]
v_north_unc =  summary.iloc[1,1]



x = t_east
y = east

with pm.Model() as linear_model:
    #Intercept
    intercept = pm.Normal('Intercept' , mu = 0, sd = 10)
    
    #Slope
    slope =  pm.Normal('Slope' , mu =0,  sd = 10)
    
    #Standard Deviation
    sigma  = pm.HalfNormal('sigma', sd = 10)
    
    #Estimation of Mean
    mean = intercept + slope*x
    
    #observed values
    
    Y_obs = pm.Normal('Y_obs', mu = mean, sd = sigma, observed = y)
    
    #sampler
    step = pm.NUTS()
    
    #Posterior Distribution
    linear_trace = pm.sample(10000,step)
    

pm.traceplot(linear_trace, figsize = (20, 20))
plt.savefig('ALBH - East (MCMC)')

summary = pm.summary(linear_trace)
v_east = summary.iloc[1,0]
v_east_unc =  summary.iloc[1,1]

print('V_east = ', v_east)
print('V_east_unc = ', v_east_unc)
print('V_north = ', v_north)
print('V_north_unc = ', v_north_unc)
# Out:
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, Slope, Intercept]
# Sampling 2 chains, 0 divergences: 100%|██████████| 21000/21000 [03:03<00:00, 114.13draws/s]
# The acceptance probability does not match the target. It is 0.9892619153642813, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9924114961861498, but should be close to 0.8. Try to increase the number of tuning steps.
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, Slope, Intercept]
# Sampling 2 chains, 0 divergences: 100%|██████████| 21000/21000 [02:44<00:00, 127.46draws/s]
# The acceptance probability does not match the target. It is 0.9854339484695923, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9826839901010774, but should be close to 0.8. Try to increase the number of tuning steps.
# V_east =  -8.011
# V_east_unc =  0.039
# V_north =  -7.624
# V_north_unc =  0.026
